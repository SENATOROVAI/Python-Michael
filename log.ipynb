# %%
07.12.2023

1. Изучили Git hub
    - Fork это копирование чужого репозитория в личный акканут для дальнейшого пулл ревкеста.
    - Pull request перенос правок из личного репозитория в форкнутый
    - Commit фиксирование правок
2. Прошлись немного по math, выявили, что я знаю, что такое мода, выборка, на генеральной совокупности затупил, однако вспомнил при помощи SENATOROVA, что это просто вся совокупность данных
3. Установоили GitHub Desktop, для более простой работы с commit и GitHub-ом
4. Настройка VScode
5. Знакомство с TG чатом и подразделами.

# %%
11.12.2023

1. Повторили как делать Push and Commit in GitHub
2. Продолжили настройку VScode, установили: 
    linter - инструмент анализа и поиска ошибок (flake 8)
    Black(shift+alf+f) - инструмент автоформатирования кода по PEP8 
    Anaconda  - Виртуальное окружение, отдельная папка с питоном и его зависимостями
4. Научились выгружать и читать зависимоти
5. Повторили и подтянули, как парсить список и искать максимальное значение в нем
6. Вспомнили операции умножения и деления, как целочисленное, так и нет
7. Повторили булевые операции, а также по битовые действия (умножения)

# %%
28.12.2023
1. Изучили что значит If __name__ #Дандер нейм /содержится название модуля, по умолчанию там main - главный файл, называется точкой входа. Место откуда происходит запуск программы
    # "__main__"  # Файл в котором мы работаем. С помощью данного метода, можем запускать функцию, например, только в главном файле, в других рабоать не будет
    # Файл с рассширением .py - модуль
2. Изучили mypy с помощью которого можем чекать тип переменных
3. попали в ядро Python
4. Познакомились с CODEforce
5. Изучили While TRUE
6. Изучили немного что такое пайтон, а именно что за язык - Multi-paradigm, because object-oriented procedural (imperative), functional. 
7. Узнали, что существуют различные расширения, что позволяет ускорить питоню pypy python 3  or 2. А также namba py, которая позволяет работать на скоростях C++

# %%
12.01.2024
1. Создали аккаунт на Kaggle. Немного прокачали Kaggle
2. Посмотрели структуру данных
3. Посмотрели задачи на Codeforece
4. Закрепили работу с GIT

# %%
17.01.2024
1. Научились проверять объекты на иносты с помощью is
2. Изучили что такое garabage collector и как он работает
3. Начали изученние class. 
    3.1 выявиди, какое наследование класса может быть: явное, не явное
    3.2 создали класс
4. Вспомнили что такое # conda - пакетный менеджер (ds) 
                        # pip - пакетный менеджер (python default)

# %%
25.01.2024
1. Изучили функции
2. рассмотрели функции, которые вызывают сами же себя
3. рассмотрели callback - функция, которая передается в другую функцию в качестве аргумента и затем вызывается
4. изучили интроспецию - сигнатура функции
5. рассмотрели области функций

# %%
14.02.2024
1. Разобрали Big(O) time complexity - худший случай алгоритма, space complexity(Сложность по памяти/пространственная сложность
2. Разобрали RAM
3. изучили хэш таблица
4. стек - структура данных, работает по lifo -last in firs out(последний эл. добавлленый в стек, будет извлечен первым)

# %%
28.02.2024
1. Изучили парсинг 
2. Сделали запрос к веб странице
3. посмотрели структуру страницы 
4. затронули html и json
